# %%
import pandas as pd

# %%
df = pd.read_csv("weatheranalysisproject.csv")

# %%
df.head()
## show first five column of data
# Out:
#      Date  Temp(F)  Humidity  wind speed    AQI
# 0  Mar-01     72.8      62.9         5.5  160.0
# 1  Mar-02     72.8      64.4         6.5  179.0
# 2  Mar-03     73.6      59.5         7.4  171.0
# 3  Mar-04     76.8      60.1         5.6  157.0
# 4  Mar-05     78.1      62.9         5.3  154.0

# %%
df.info() # to check data info
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        28 non-null     str
#  1   Temp(F)     28 non-null     float64
#  2   Humidity    28 non-null     float64
#  3   wind speed  28 non-null     float64
#  4   AQI         28 non-null     float64
# dtypes: float64(4), str(1)
# memory usage: 1.3 KB

# %%
df.isnull().sum()
# Out:
# Date          1
# Temp(F)       1
# Humidity      1
# wind speed    1
# AQI           1
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        28 non-null     str
#  1   Temp(F)     28 non-null     float64
#  2   Humidity    28 non-null     float64
#  3   wind speed  28 non-null     float64
#  4   AQI         28 non-null     float64
# dtypes: float64(4), str(1)
# memory usage: 1.2 KB

# %%
df.describe()
# Out:
#          Temp(F)   Humidity  wind speed         AQI
# count  28.000000  28.000000   28.000000   28.000000
# mean   75.935714  64.385714    3.317857  159.214286
# std     3.957760   9.849035    1.842714   20.111462
# min    64.300000  46.700000    0.600000  115.000000
# 25%    73.600000  59.500000    1.900000  151.000000
# 50%    76.900000  62.900000    2.850000  158.000000
# 75%    78.225000  66.725000    4.875000  169.500000
# max    82.200000  95.500000    7.400000  206.000000

# %%
df.corr(numeric_only=True)
# Out:
#              Temp(F)  Humidity  wind speed       AQI
# Temp(F)     1.000000 -0.796936   -0.042800  0.133631
# Humidity   -0.796936  1.000000   -0.261464  0.189241
# wind speed -0.042800 -0.261464    1.000000 -0.139722
# AQI         0.133631  0.189241   -0.139722  1.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["Humidity"],df["AQI"])
plt.xlabel("Humidity")
plt.ylabel("AQI")
plt.title("Humidity vs AQI")
plt.show()

# %%
plt.scatter(df["wind speed"],df["AQI"])
plt.xlabel("wind speed")
plt.ylabel("AQI")
plt.title("wind speed vs AQI")
plt.show()

# %%
plt.scatter(df["Temp(F)"],df["AQI"])
plt.xlabel("Temperature")
plt.ylabel("AQI")
plt.title("temperature vs AQI")
plt.show()

# %%
plt.scatter(df["Temp(F)"],df["Humidity"],c=df["AQI"])
plt.xlabel("Temperature")
plt.ylabel("Humidity")
plt.title("Temp + humidity vs AQI")
plt.colorbar(label="AQI")
plt.show()

# %%
plt.scatter(df["Temp(F)"],df["Humidity"],c=df["AQI"],s=df["wind speed"]*20)
plt.xlabel("Temperature")
plt.ylabel("Humidity")
plt.title("Temp + humidity + wind vs AQI")
plt.colorbar(label="AQI")
plt.show()

# %%
## humidity >70 and wind speed < 2
filtered_df = df[(df["Humidity"]>70) & (df["wind speed"]<2)]
filtered_df
# Out:
#       Date  Temp(F)  Humidity  wind speed    AQI
# 17  Mar-18     74.9      70.3         1.6  173.0
# 19  Mar-20     64.3      95.5         1.5  158.0

# %%
filtered_df = df[(df["Humidity"]<60) & (df["wind speed"]>4)]
filtered_df
# Out:
#       Date  Temp(F)  Humidity  wind speed    AQI
# 2   Mar-03     73.6      59.5         7.4  171.0
# 11  Mar-12     82.2      46.7         5.3  152.0
# 12  Mar-13     79.6      55.4         5.1  154.0
# 14  Mar-15     75.1      59.6         4.8  122.0
# 15  Mar-16     75.4      55.5         4.4  115.0

# %%
df.sort_values(by = "AQI", ascending=False)
# Out:
#       Date  Temp(F)  Humidity  wind speed    AQI
# 9   Mar-10     80.9      65.4         1.0  206.0
# 6   Mar-07     77.8      64.1         2.0  199.0
# 8   Mar-09     79.0      71.0         3.6  184.0
# 1   Mar-02     72.8      64.4         6.5  179.0
# 7   Mar-08     78.1      65.4         2.4  177.0
# 17  Mar-18     74.9      70.3         1.6  173.0
# 2   Mar-03     73.6      59.5         7.4  171.0
# 10  Mar-11     80.0      58.4         2.4  169.0
# 23  Mar-24     75.3      66.6         0.6  165.0
# 5   Mar-06     77.3      64.5         3.9  165.0
# 24  Mar-25     77.8      59.5         2.6  164.0
# 0   Mar-01     72.8      62.9         5.5  160.0
# 19  Mar-20     64.3      95.5         1.5  158.0
# 20  Mar-21     69.5      77.4         2.4  158.0
# 21  Mar-22     72.9      67.1         3.8  158.0
# 3   Mar-04     76.8      60.1         5.6  157.0
# 16  Mar-17     74.9      62.0         0.8  156.0
# 4   Mar-05     78.1      62.9         5.3  154.0
# ...

# %%
df.sort_values(by = "AQI")
# Out:
#       Date  Temp(F)  Humidity  wind speed    AQI
# 15  Mar-16     75.4      55.5         4.4  115.0
# 14  Mar-15     75.1      59.6         4.8  122.0
# 26  Mar-27     77.0      62.6         2.3  127.0
# 27  Mar-28     78.6      59.8         1.4  141.0
# 25  Mar-26     81.4      51.4         1.3  147.0
# 22  Mar-23     73.6      75.0         3.8  147.0
# 13  Mar-14     77.0      55.5         2.5  148.0
# 11  Mar-12     82.2      46.7         5.3  152.0
# 18  Mar-19     69.5      84.3         3.1  152.0
# 12  Mar-13     79.6      55.4         5.1  154.0
# 4   Mar-05     78.1      62.9         5.3  154.0
# 16  Mar-17     74.9      62.0         0.8  156.0
# 3   Mar-04     76.8      60.1         5.6  157.0
# 19  Mar-20     64.3      95.5         1.5  158.0
# 20  Mar-21     69.5      77.4         2.4  158.0
# 21  Mar-22     72.9      67.1         3.8  158.0
# 0   Mar-01     72.8      62.9         5.5  160.0
# 24  Mar-25     77.8      59.5         2.6  164.0
# ...

# %% [markdown]
# ### model
# step 1 : Prepare data

# %%
x = df[["Temp(F)","Humidity","wind speed"]]
y = df["AQI"] ## x = input and y = output

# %% [markdown]
# step 2: split data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 11.601195053482732

# %%
model.coef_
# Out:
# array([3.63661597, 1.53398461, 1.3301663 ])

# %%
df[["Temp(F)","Humidity","wind speed"]].columns
# Out:
# Index(['Temp(F)', 'Humidity', 'wind speed'], dtype='str')

# %%
model.predict([[80,60,3]])
# Out:
# /home/nextgencoders/Desktop/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([165.32783786])

# %%
model.predict([[70,50,6]])
# Out:
# /home/nextgencoders/Desktop/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([117.61233098])

# %%
model.predict([[65,90,1]])
# Out:
# /home/nextgencoders/Desktop/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([154.13780391])

# %%
model.predict([[78.8,39,12.4]])
# Out:
# /home/nextgencoders/Desktop/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([141.25378519])

# %%
model.predict([[89.6,17,11.682]])
# Out:
# /home/nextgencoders/Desktop/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([145.82651691])
